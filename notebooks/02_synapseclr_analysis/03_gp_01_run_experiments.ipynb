# %% [markdown]
# ## Gaussion Process Regression
#
# This notebook is used for performing various GP experiments and saving the output for further analysis.

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch

from synapse_utils import io

import pyro
import pyro.contrib.gp as gp
import pyro.distributions as dist

from pyro.infer import TraceMeanField_ELBO
from pyro.infer.util import torch_backward, torch_item

from sklearn.decomposition import PCA

import pickle

from collections import defaultdict

from sklearn.metrics import roc_curve, roc_auc_score
# from sklearn.cluster import KMeans
from cuml import KMeans

# assert pyro.__version__.startswith('1.7.0')
pyro.set_rng_seed(0)

# %% [markdown]
# ## Train and test data

# %%
repo_root = '../..'
checkpoint_path = '../../output/checkpoint__synapseclr__so3__second_stage'
output_root = '../../output/gp'

node_idx_list = [0, 1, 2, 3]
reload_epoch = 99
feature_hook = 'encoder.fc'
dataset_path = '../../data/MICrONS__L23__8_8_40__processed'
l2_normalize = False

contamination_indices_path = os.path.join(
    checkpoint_path, 'indices', 'contamination_meta_df_row_indices.npy')

device = torch.device('cuda')
dtype = torch.float32

training_fraction = 0.9
perform_class_balancing = True
perform_pca = True
n_pca_features = 50
k_fold = 3
random_seed = 42

kernel_type = 'rbf'
n_inducing_points = 1000
z_jitter = 0.1
elbo_type = 'mean-field'

# initial kernel parameters
init_gaussian_variance = 0.5
init_rbf_variance = 1.0
init_rbf_lengthscale = 0.5
init_linear_variance = 1.0
init_constant_variance = 1.0
init_laplace_variance = 1.0
init_laplace_lengthscale = 0.5

print_loss_every = 1000
eval_every = 1000

lr = 0.001
num_optim_steps = 10_000 + 1

trait_key_list = [
    'cleft_size_log1p_zscore',
    'presyn_soma_dist_log1p_zscore',
    'postsyn_soma_dist_log1p_zscore',
    'mito_size_pre_vx_log1p_zscore_zi',
    'mito_size_post_vx_log1p_zscore_zi',
    'pre_and_post_cell_types',
    'pre_cell_type',
    'post_cell_type',
    'has_mito_pre',
    'has_mito_post'
]

trait_type_list = [
    'continuous',
    'continuous',
    'continuous',
    'continuous',
    'continuous',
    'categorical',
    'categorical',
    'categorical',
    'categorical',
    'categorical'
]

trait_num_categories_list = [
    None,
    None,
    None,
    None,
    None,
    4,
    2,
    2,
    2,
    2
]

trait_control_list = [
    None,
    None,
    None,
    'has_mito_pre',
    'has_mito_post',
    None,
    None,
    None,
    None,
    None
]

def get_augmented_table(meta_ext_df: pd.DataFrame) -> pd.DataFrame:
    
    # combined pre and post cell types
    pre_post_cell_types_map = {
        (0, 0): 0,
        (0, 1): 1,
        (1, 0): 2,
        (1, 1): 3,
    }
    
    pre_cell_type_values = meta_ext_df['pre_cell_type'].values
    post_cell_type_values = meta_ext_df['post_cell_type'].values
    pre_post_cell_type_values = np.asarray(list(
        map(pre_post_cell_types_map.get,
            zip(pre_cell_type_values, post_cell_type_values))))
    
    aug_meta_ext_df = meta_ext_df.copy()
    aug_meta_ext_df['pre_and_post_cell_types'] = pre_post_cell_type_values
    
    return aug_meta_ext_df

def generate_manifest(var_dict: dict) -> dict:
    attributes = [
        'experiment_prefix',
        'checkpoint_path',
        'reload_epoch',
        'feature_hook',
        'l2_normalize',
        'k_fold',
        'perform_class_balancing',
        'perform_pca',
        'n_pca_features',
        'n_inducing_points',
        'z_jitter',
        'init_rbf_variance',
        'init_rbf_lengthscale',
        'init_gaussian_variance',
        'init_linear_variance',
        'init_constant_variance',
        'kernel_type',
        'elbo_type',
        'lr',
        'num_optim_steps',
        'trait_key_list',
        'trait_type_list',
        'trait_num_categories_list',
        'trait_control_list'
    ]
    manifest = {attribute: var_dict[attribute] for attribute in attributes}
    return manifest

# %%
# first wave
experiment_prefix = 'first_wave'
perform_pca = False

experiment_manifest_list = []

kernel_type = 'rbf'
n_inducing_points = 1000
for feature_hook, l2_normalize in [
        ('encoder.fc', False),
        ('projector.mlp.0', False),
        ('projector.mlp.3', False),
        ('projector.mlp.3', True)]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)
    
n_inducing_points = 50
for feature_hook, l2_normalize in [
        ('encoder.fc', False),
        ('projector.mlp.0', False),
        ('projector.mlp.3', False),
        ('projector.mlp.3', True)]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

# %%
# second wave
experiment_prefix = 'second_wave'
perform_pca = False

experiment_manifest_list = []

kernel_type = 'laplace'
feature_hook = 'encoder.fc'
l2_normalize = False
for n_inducing_points in [10, 20, 50, 100, 200, 500]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

kernel_type = 'linear'
feature_hook = 'encoder.fc'
l2_normalize = False
for n_inducing_points in [10, 5]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

# %%
# third wave
experiment_prefix = 'third_wave'
perform_pca = True
kernel_type = 'rbf'
feature_hook = 'encoder.fc'
l2_normalize = False

experiment_manifest_list = []

for n_pca_features in [50, 100]:
    for n_inducing_points in [50, 500]:        
        manifest = generate_manifest(locals())
        experiment_manifest_list.append(manifest)

# %%
# fourth wave
experiment_prefix = 'fourth_wave'
perform_pca = False
kernel_type = 'rbf'
feature_hook = 'encoder.fc'
l2_normalize = False

experiment_manifest_list = []

for n_inducing_points in [10, 20, 50, 100, 200, 5, 300, 400, 500, 600, 700, 800, 900, 1000]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

# %%
# fifth wave
experiment_prefix = 'fifth_wave'
checkpoint_path = '/home/jupyter/dev/data/checkpoint__medicalnet__resnet18_23_dataset'
node_idx_list = [0]
reload_epoch = 0
perform_pca = False
kernel_type = 'rbf'
feature_hook = 'encoder.fc'
l2_normalize = False

experiment_manifest_list = []

for n_inducing_points in [5, 10, 20, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

# %%
# sixth wave
experiment_prefix = 'sixth_wave'
checkpoint_path = '/home/jupyter/dev/data/checkpoint__random'
node_idx_list = [0]
reload_epoch = 0
perform_pca = False
kernel_type = 'rbf'
feature_hook = 'encoder.fc'
l2_normalize = False

experiment_manifest_list = []

for n_inducing_points in [5, 10, 20, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]:
    manifest = generate_manifest(locals())
    experiment_manifest_list.append(manifest)

# %%
save_results = True
notebook_mode = True

if not notebook_mode:
    start_experiment_index = int(sys.argv[1])
    end_experiment_index = int(sys.argv[2])

else:
    start_experiment_index = 0
    end_experiment_index = len(experiment_manifest_list)

# %%
for experiment_index, manifest in list(
        enumerate(experiment_manifest_list))[start_experiment_index:end_experiment_index]:

    # set local variables from the manifest
    for key, value in manifest.items():
        setattr(sys.modules[__name__], key, value)

    # basic checks
    n_traits = len(trait_key_list)
    assert len(trait_type_list) == n_traits
    assert len(trait_control_list) == n_traits

    # announce
    print(f'Starting experiment {experiment_index} ...')
    print(manifest)
    print()

    # load features
    features_nf, meta_df, meta_ext_df = io.load_features(
        checkpoint_path,
        node_idx_list,
        reload_epoch,
        feature_hook=feature_hook,
        dataset_path=dataset_path,
        l2_normalize=l2_normalize,
        contamination_indices_path=contamination_indices_path)
    
    # scale
    features_nf = features_nf / np.std(features_nf)
    
    if perform_pca:
        features_nf = PCA(n_pca_features).fit_transform(features_nf)
    
    # add combined columns to the table (if necessary)
    meta_ext_df = get_augmented_table(meta_ext_df)
    
    # generating cross-validation data splits
    rng = np.random.RandomState(random_seed)
    n_traits = len(trait_key_list)

    synapse_ids_to_meta_ext_df_row_idx_map = {
        synapse_id: row_idx
        for row_idx, synapse_id in enumerate(meta_ext_df['synapse_id'].values)}

    synapse_ids_to_meta_df_row_idx_map = {
        synapse_id: row_idx
        for row_idx, synapse_id in enumerate(meta_df['synapse_id'].values)}

    train_meta_ext_df_dict = dict()
    test_meta_ext_df_dict = dict()

    for i in range(n_traits):

        trait_key = trait_key_list[i]
        trait_type = trait_type_list[i]
        trait_num_categories = trait_num_categories_list[i]
        trait_control = trait_control_list[i]

        if trait_type == 'categorical':
            per_category_indices = [
                np.nonzero(meta_ext_df[trait_key].values == category_index)[0]
                for category_index in range(trait_num_categories)]
        else:
            per_category_indices = None

        for k in range(k_fold):

            # if continuous, no class balancing is needed
            if trait_type == 'continuous':

                n_annotated = len(meta_ext_df)
                n_train = int(n_annotated * training_fraction)
                n_test = n_annotated - n_train
                perm = rng.permutation(n_annotated)
                train_indices = perm[:n_train]
                test_indices = perm[n_train:]

            # if categorical, perform class balancing
            elif trait_type == 'categorical':

                if perform_class_balancing:

                    n_annotated = len(meta_ext_df)
                    n_train = int(n_annotated * training_fraction)
                    n_test = n_annotated - n_train
                    n_train_per_category = n_train // trait_num_categories
                    n_test_per_category = n_test // trait_num_categories

                    train_indices = []
                    test_indices = []

                    for category_index in range(trait_num_categories):

                        # partition the category conditional annotations into disjoint test and train groups
                        n_annotated = len(per_category_indices[category_index])
                        n_train = int(n_annotated * training_fraction)
                        n_test = n_annotated - n_train
                        assert n_train > 0
                        assert n_test > 0

                        perm = rng.permutation(n_annotated)
                        all_train_indices = per_category_indices[category_index][perm[:n_train]]
                        all_test_indices = per_category_indices[category_index][perm[n_train:]]

                        train_indices += rng.choice(
                            all_train_indices, replace=True, size=n_train_per_category).tolist()
                        test_indices += rng.choice(
                            all_test_indices, replace=True, size=n_test_per_category).tolist()

                else:

                    n_annotated = len(meta_ext_df)
                    n_train = int(n_annotated * training_fraction)
                    n_test = n_annotated - n_train
                    perm = rng.permutation(n_annotated)
                    train_indices = perm[:n_train]
                    test_indices = perm[n_train:]

            else:
                raise ValueError

            rng.shuffle(train_indices)
            rng.shuffle(test_indices)

            train_meta_ext_df_dict[(i, k)] = meta_ext_df.iloc[train_indices].copy().reset_index(drop=True)
            test_meta_ext_df_dict[(i, k)] = meta_ext_df.iloc[test_indices].copy().reset_index(drop=True)

    # container for evaluations
    eval_container_dict = dict()
    loss_container_dict = dict()

    for k in range(k_fold):
        for trait_index in range(n_traits):

            # setup
            trait_key = trait_key_list[trait_index]
            trait_type = trait_type_list[trait_index]
            trait_num_categories = trait_num_categories_list[trait_index]
            trait_control = trait_control_list[trait_index]

            train_meta_ext_df = train_meta_ext_df_dict[(trait_index, k)]
            test_meta_ext_df = test_meta_ext_df_dict[(trait_index, k)]

            assert trait_type in {'continuous', 'categorical'}

            print(f'Running GP for {trait_key}, type = {trait_type}, fold = {k}, control = {trait_control}')

            # do we need to censor the train and test data?
            if trait_control is not None:
                train_meta_ext_df = train_meta_ext_df[train_meta_ext_df[trait_control] == 1]
                test_meta_ext_df = test_meta_ext_df[test_meta_ext_df[trait_control] == 1]
                assert len(train_meta_ext_df) > 0
                assert len(test_meta_ext_df) > 0

            train_trait_values_n = torch.tensor(
                train_meta_ext_df[trait_key].values,
                device=device, dtype=dtype)

            test_trait_values_n = torch.tensor(
                test_meta_ext_df[trait_key].values,
                device=device, dtype=dtype)

            print(f'Number of training data points: {len(train_trait_values_n)}')
            print(f'Number of test data points: {len(test_trait_values_n)}')

            # select the corresponding representations
            train_indices = list(map(synapse_ids_to_meta_df_row_idx_map.get, train_meta_ext_df['synapse_id'].values))
            test_indices = list(map(synapse_ids_to_meta_df_row_idx_map.get, test_meta_ext_df['synapse_id'].values))
            train_z_nf = torch.tensor(
                features_nf[train_indices],
                device=device, dtype=dtype)
            test_z_nf = torch.tensor(
                features_nf[test_indices],
                device=device, dtype=dtype)

            ### run GP ##
            
            # initialize the inducing inputs
            x_dim = features_nf.shape[-1]

            # select a subset of synapse representations + random jitter as inducing points
            Xu = torch.tensor(
                features_nf[rng.permutation(len(features_nf))[:n_inducing_points]],
                device=device, dtype=dtype)
            Xu = Xu + z_jitter * torch.randn_like(Xu)

            # set the covariates (X) to the representations
            X = train_z_nf

            # set the readout (y) to the trait
            y = train_trait_values_n

            # initialize the kernel, likelihood, and model
            pyro.clear_param_store()

            if trait_type == 'continuous':
                likelihood = gp.likelihoods.Gaussian(
                    variance=torch.tensor(init_gaussian_variance))
                latent_shape = None

            elif trait_type == 'categorical':
                likelihood = gp.likelihoods.MultiClass(num_classes=trait_num_categories)
                latent_shape = (trait_num_categories,)
            else:
                raise ValueError

            # instantiate the GP model
            if kernel_type == 'rbf':
                rbf_kernel = gp.kernels.RBF(
                    input_dim=x_dim,
                    variance=torch.tensor(init_rbf_variance),
                    lengthscale=torch.tensor(init_rbf_lengthscale))
                kernel = rbf_kernel
                
            elif kernel_type == 'linear':
                linear_kernel = gp.kernels.Linear(
                    input_dim=x_dim,
                    variance=torch.tensor(init_linear_variance))
                constant_kernel = gp.kernels.Constant(
                    input_dim=x_dim,
                    variance=torch.tensor(init_constant_variance))
                kernel = gp.kernels.Sum(linear_kernel, constant_kernel)
                
            elif kernel_type == 'laplace':
                laplace_kernel = gp.kernels.Exponential(
                    input_dim=x_dim,
                    variance=torch.tensor(init_laplace_variance),
                    lengthscale=torch.tensor(init_laplace_lengthscale))
                kernel = laplace_kernel

            else:
                raise ValueError
                
            kernel = kernel.to(device)
            vsgp = gp.models.VariationalSparseGP(
                X, y, kernel,
                Xu=Xu,
                likelihood=likelihood,
                whiten=True,
                jitter=1e-3,
                latent_shape=latent_shape).to(device)

            optimizer = torch.optim.Adam(vsgp.parameters(), lr=lr)
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_optim_steps)

            if elbo_type == 'mean-field':
                loss_fn = pyro.infer.TraceMeanField_ELBO().differentiable_loss

            elif elbo_type == 'map':
                loss_fn = pyro.infer.Trace_ELBO().differentiable_loss

            else:
                raise ValueError

            def closure():
                optimizer.zero_grad()
                loss = loss_fn(vsgp.model, vsgp.guide)
                torch_backward(loss)
                return loss

            loss_container_dict[(trait_index, k)] = []
            eval_container_dict[(trait_index, k)] = defaultdict(list)

            for i_iter in range(num_optim_steps):

                # otpimizer step
                loss = optimizer.step(closure)

                # log
                if i_iter % print_loss_every == 0:
                    print(f'iter: {i_iter}, lr: {scheduler.get_last_lr()[0]:.5f}, loss: {torch_item(loss)}')

                # save loss
                loss_container_dict[(trait_index, k)].append((i_iter, torch_item(loss)))

                # scheduler step
                scheduler.step()

                # evaluate
                if i_iter % eval_every == 0:

                    for eval_set in {'train', 'test'}:

                        if eval_set == 'test':
                            X_test = test_z_nf
                            y_test = test_trait_values_n

                        elif eval_set == 'train':
                            X_test = train_z_nf
                            y_test = train_trait_values_n

                        else:
                            raise ValueError

                        with torch.no_grad():
                            y_test_pred_mean, y_test_pred_cov = vsgp(X_test, full_cov=False)
                            y_test_pred_sd = y_test_pred_cov.sqrt()

                        if trait_type == 'continuous':
                            residual_variance = torch.var(y_test_pred_mean - y_test).item()
                            total_variance = torch.var(y_test).item()
                            explained_variance = 1. - residual_variance / total_variance
                            eval_container_dict[(trait_index, k)][f'{eval_set}_explained_variance'].append((i_iter, explained_variance))
                            print(f'\t[{eval_set} eval] explained variance: {explained_variance:3f}')

                        elif trait_type == 'categorical':
                            y_test_pred_soft = torch.softmax(y_test_pred_mean, dim=0).cpu().numpy()
                            y_test_pred_hard = torch.softmax(y_test_pred_mean, dim=0).argmax(dim=0).cpu().numpy()
                            y_test_hard = y_test.type(torch.int).cpu().numpy()

                            # calculate confusion matrix
                            confusion_matrix = np.zeros((trait_num_categories, trait_num_categories))
                            for actual_category, pred_category in zip(y_test_hard, y_test_pred_hard):
                                confusion_matrix[actual_category, pred_category] += 1
                            eval_container_dict[(trait_index, k)][f'{eval_set}_confusion_matrix'].append((i_iter, confusion_matrix))

                            # calculate ROC curve and AUCROC
                            for i_category in range(trait_num_categories):
                                scores = y_test_pred_soft[i_category, :]
                                actual = (y_test_hard == i_category).astype(int)
                                fpr, tpr, threshold = roc_curve(actual, scores)
                                auc = roc_auc_score(actual, scores)
                                eval_container_dict[(trait_index, k)][f'{eval_set}_{i_category}_roc_fpr'].append((i_iter, fpr))
                                eval_container_dict[(trait_index, k)][f'{eval_set}_{i_category}_roc_tpr'].append((i_iter, tpr))
                                eval_container_dict[(trait_index, k)][f'{eval_set}_{i_category}_roc_thresholds'].append((i_iter, threshold))
                                eval_container_dict[(trait_index, k)][f'{eval_set}_{i_category}_roc_auc'].append((i_iter, auc))
                                print(f'\t[{eval_set} eval] category {i_category} AUCROC: {auc:3f}')

                        else:
                            raise ValueError

    # save the results
    if save_results:
        
        os.makedirs(output_root, exist_ok=True)
        output_file_name = f'experiment__{experiment_prefix}__{experiment_index}.pkl'

        with open(os.path.join(output_root, output_file_name), 'wb') as f:
            pickle.dump(manifest, f)
            pickle.dump(eval_container_dict, f)
            pickle.dump(loss_container_dict, f)
# Out:
# Starting experiment 0 ...
# {'experiment_prefix': 'sixth_wave', 'checkpoint_path': '/home/jupyter/dev/data/checkpoint__random', 'reload_epoch': 0, 'feature_hook': 'encoder.fc', 'l2_normalize': False, 'k_fold': 3, 'perform_class_balancing': True, 'perform_pca': False, 'n_pca_features': 50, 'n_inducing_points': 5, 'z_jitter': 0.1, 'init_rbf_variance': 1.0, 'init_rbf_lengthscale': 0.5, 'init_gaussian_variance': 0.5, 'init_linear_variance': 1.0, 'init_constant_variance': 1.0, 'kernel_type': 'rbf', 'elbo_type': 'mean-field', 'lr': 0.001, 'num_optim_steps': 10001, 'trait_key_list': ['cleft_size_log1p_zscore', 'presyn_soma_dist_log1p_zscore', 'postsyn_soma_dist_log1p_zscore', 'mito_size_pre_vx_log1p_zscore_zi', 'mito_size_post_vx_log1p_zscore_zi', 'pre_and_post_cell_types', 'pre_cell_type', 'post_cell_type', 'has_mito_pre', 'has_mito_post'], 'trait_type_list': ['continuous', 'continuous', 'continuous', 'continuous', 'continuous', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical'], 'trait_num_categories_list': [None, None, None, None, None, 4, 2, 2, 2, 2], 'trait_control_list': [None, None, None, 'has_mito_pre', 'has_mito_post', None, None, None, None, None]}
#
# Running GP for cleft_size_log1p_zscore, type = continuous, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7351.3662109375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6618.99072265625
# 	[train eval] explained variance: 0.170390
# 	[test eval] explained variance: 0.159042
# iter: 2000, lr: 0.00090, loss: 6405.45703125
# 	[train eval] explained variance: 0.220709
# 	[test eval] explained variance: 0.213605
# iter: 3000, lr: 0.00079, loss: 6230.43505859375
# 	[train eval] explained variance: 0.271811
# 	[test eval] explained variance: 0.269943
# iter: 4000, lr: 0.00065, loss: 6063.91015625
# 	[train eval] explained variance: 0.315447
# 	[test eval] explained variance: 0.311828
# iter: 5000, lr: 0.00050, loss: 5931.15869140625
# 	[train eval] explained variance: 0.347157
# 	[test eval] explained variance: 0.342489
# iter: 6000, lr: 0.00035, loss: 5845.64794921875
# 	[train eval] explained variance: 0.365770
# 	[test eval] explained variance: 0.359542
# iter: 7000, lr: 0.00021, loss: 5797.45361328125
# 	[train eval] explained variance: 0.375778
# 	[test eval] explained variance: 0.368210
# iter: 8000, lr: 0.00010, loss: 5772.82861328125
# 	[train eval] explained variance: 0.380708
# 	[test eval] explained variance: 0.372463
# iter: 9000, lr: 0.00002, loss: 5762.97509765625
# 	[train eval] explained variance: 0.382539
# 	[test eval] explained variance: 0.373996
# iter: 10000, lr: 0.00000, loss: 5761.58740234375
# 	[train eval] explained variance: 0.382867
# 	[test eval] explained variance: 0.374270
# Running GP for presyn_soma_dist_log1p_zscore, type = continuous, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7261.853515625
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6812.515625
# 	[train eval] explained variance: 0.023627
# 	[test eval] explained variance: 0.022260
# iter: 2000, lr: 0.00090, loss: 6708.056640625
# 	[train eval] explained variance: 0.027912
# 	[test eval] explained variance: 0.020315
# iter: 3000, lr: 0.00079, loss: 6602.2060546875
# 	[train eval] explained variance: 0.033100
# 	[test eval] explained variance: 0.013690
# iter: 4000, lr: 0.00065, loss: 6537.6220703125
# 	[train eval] explained variance: 0.038943
# 	[test eval] explained variance: 0.011170
# iter: 5000, lr: 0.00050, loss: 6490.02197265625
# 	[train eval] explained variance: 0.044994
# 	[test eval] explained variance: 0.010425
# iter: 6000, lr: 0.00035, loss: 6457.47802734375
# 	[train eval] explained variance: 0.050249
# 	[test eval] explained variance: 0.010450
# iter: 7000, lr: 0.00021, loss: 6438.0361328125
# 	[train eval] explained variance: 0.054020
# 	[test eval] explained variance: 0.010315
# iter: 8000, lr: 0.00010, loss: 6427.6220703125
# 	[train eval] explained variance: 0.055999
# 	[test eval] explained variance: 0.009873
# iter: 9000, lr: 0.00002, loss: 6423.80029296875
# 	[train eval] explained variance: 0.056746
# 	[test eval] explained variance: 0.009690
# iter: 10000, lr: 0.00000, loss: 6422.91796875
# 	[train eval] explained variance: 0.056828
# 	[test eval] explained variance: 0.009578
# Running GP for postsyn_soma_dist_log1p_zscore, type = continuous, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7350.40771484375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6421.853515625
# 	[train eval] explained variance: 0.186563
# 	[test eval] explained variance: 0.176870
# iter: 2000, lr: 0.00090, loss: 5776.26025390625
# 	[train eval] explained variance: 0.346457
# 	[test eval] explained variance: 0.343075
# iter: 3000, lr: 0.00079, loss: 5536.052734375
# 	[train eval] explained variance: 0.416755
# 	[test eval] explained variance: 0.408856
# iter: 4000, lr: 0.00065, loss: 5397.00732421875
# 	[train eval] explained variance: 0.451462
# 	[test eval] explained variance: 0.439082
# iter: 5000, lr: 0.00050, loss: 5316.1337890625
# 	[train eval] explained variance: 0.469647
# 	[test eval] explained variance: 0.453962
# iter: 6000, lr: 0.00035, loss: 5271.86865234375
# 	[train eval] explained variance: 0.479296
# 	[test eval] explained variance: 0.460889
# iter: 7000, lr: 0.00021, loss: 5247.9404296875
# 	[train eval] explained variance: 0.484422
# 	[test eval] explained variance: 0.464020
# iter: 8000, lr: 0.00010, loss: 5236.01025390625
# 	[train eval] explained variance: 0.486969
# 	[test eval] explained variance: 0.465491
# iter: 9000, lr: 0.00002, loss: 5231.25439453125
# 	[train eval] explained variance: 0.487967
# 	[test eval] explained variance: 0.465967
# iter: 10000, lr: 0.00000, loss: 5230.4560546875
# 	[train eval] explained variance: 0.488104
# 	[test eval] explained variance: 0.466064
# Running GP for mito_size_pre_vx_log1p_zscore_zi, type = continuous, fold = 0, control = has_mito_pre
# Number of training data points: 3171
# Number of test data points: 346
# iter: 0, lr: 0.00100, loss: 4638.841796875
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 4225.7919921875
# 	[train eval] explained variance: 0.147427
# 	[test eval] explained variance: 0.105659
# iter: 2000, lr: 0.00090, loss: 4023.986572265625
# 	[train eval] explained variance: 0.227270
# 	[test eval] explained variance: 0.160375
# iter: 3000, lr: 0.00079, loss: 3924.7265625
# 	[train eval] explained variance: 0.260484
# 	[test eval] explained variance: 0.169283
# iter: 4000, lr: 0.00065, loss: 3852.2890625
# 	[train eval] explained variance: 0.281011
# 	[test eval] explained variance: 0.169595
# iter: 5000, lr: 0.00050, loss: 3800.057373046875
# 	[train eval] explained variance: 0.295512
# 	[test eval] explained variance: 0.169718
# iter: 6000, lr: 0.00035, loss: 3766.19091796875
# 	[train eval] explained variance: 0.305240
# 	[test eval] explained variance: 0.168591
# iter: 7000, lr: 0.00021, loss: 3746.36669921875
# 	[train eval] explained variance: 0.311251
# 	[test eval] explained variance: 0.167422
# iter: 8000, lr: 0.00010, loss: 3736.173583984375
# 	[train eval] explained variance: 0.314439
# 	[test eval] explained variance: 0.167171
# iter: 9000, lr: 0.00002, loss: 3732.286865234375
# 	[train eval] explained variance: 0.315649
# 	[test eval] explained variance: 0.166924
# iter: 10000, lr: 0.00000, loss: 3731.706298828125
# 	[train eval] explained variance: 0.315801
# 	[test eval] explained variance: 0.166957
# Running GP for mito_size_post_vx_log1p_zscore_zi, type = continuous, fold = 0, control = has_mito_post
# Number of training data points: 3536
# Number of test data points: 393
# iter: 0, lr: 0.00100, loss: 5135.2109375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 4930.8916015625
# 	[train eval] explained variance: 0.015526
# 	[test eval] explained variance: -0.009640
# iter: 2000, lr: 0.00090, loss: 4884.9404296875
# 	[train eval] explained variance: 0.027217
# 	[test eval] explained variance: -0.004405
# iter: 3000, lr: 0.00079, loss: 4862.1884765625
# 	[train eval] explained variance: 0.036330
# 	[test eval] explained variance: -0.003084
# iter: 4000, lr: 0.00065, loss: 4839.79443359375
# 	[train eval] explained variance: 0.046038
# 	[test eval] explained variance: -0.006765
# iter: 5000, lr: 0.00050, loss: 4830.0205078125
# 	[train eval] explained variance: 0.050269
# 	[test eval] explained variance: -0.007347
# iter: 6000, lr: 0.00035, loss: 4825.53369140625
# 	[train eval] explained variance: 0.052630
# 	[test eval] explained variance: -0.007241
# iter: 7000, lr: 0.00021, loss: 4822.63525390625
# 	[train eval] explained variance: 0.053999
# 	[test eval] explained variance: -0.007063
# iter: 8000, lr: 0.00010, loss: 4821.498046875
# 	[train eval] explained variance: 0.054894
# 	[test eval] explained variance: -0.007222
# iter: 9000, lr: 0.00002, loss: 4821.0380859375
# 	[train eval] explained variance: 0.055203
# 	[test eval] explained variance: -0.007244
# iter: 10000, lr: 0.00000, loss: 4820.95068359375
# 	[train eval] explained variance: 0.055285
# 	[test eval] explained variance: -0.007264
# Running GP for pre_and_post_cell_types, type = categorical, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 560
# iter: 0, lr: 0.00100, loss: 8718.953125
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[train eval] category 2 AUCROC: 0.500000
# 	[train eval] category 3 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# 	[test eval] category 2 AUCROC: 0.500000
# 	[test eval] category 3 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 6693.61279296875
# 	[train eval] category 0 AUCROC: 0.814728
# 	[train eval] category 1 AUCROC: 0.600763
# 	[train eval] category 2 AUCROC: 0.612444
# 	[train eval] category 3 AUCROC: 0.638331
# 	[test eval] category 0 AUCROC: 0.866412
# 	[test eval] category 1 AUCROC: 0.653844
# 	[test eval] category 2 AUCROC: 0.622908
# 	[test eval] category 3 AUCROC: 0.610272
# iter: 2000, lr: 0.00090, loss: 6333.05615234375
# 	[train eval] category 0 AUCROC: 0.836254
# 	[train eval] category 1 AUCROC: 0.625684
# 	[train eval] category 2 AUCROC: 0.664113
# 	[train eval] category 3 AUCROC: 0.663639
# 	[test eval] category 0 AUCROC: 0.877381
# 	[test eval] category 1 AUCROC: 0.664371
# 	[test eval] category 2 AUCROC: 0.698214
# 	[test eval] category 3 AUCROC: 0.643248
# iter: 3000, lr: 0.00079, loss: 6227.0546875
# 	[train eval] category 0 AUCROC: 0.845860
# 	[train eval] category 1 AUCROC: 0.645701
# 	[train eval] category 2 AUCROC: 0.678230
# 	[train eval] category 3 AUCROC: 0.677657
# 	[test eval] category 0 AUCROC: 0.885323
# 	[test eval] category 1 AUCROC: 0.680000
# 	[test eval] category 2 AUCROC: 0.716088
# 	[test eval] category 3 AUCROC: 0.662551
# iter: 4000, lr: 0.00065, loss: 6160.20361328125
# 	[train eval] category 0 AUCROC: 0.859005
# 	[train eval] category 1 AUCROC: 0.662776
# 	[train eval] category 2 AUCROC: 0.688237
# 	[train eval] category 3 AUCROC: 0.689566
# 	[test eval] category 0 AUCROC: 0.898793
# 	[test eval] category 1 AUCROC: 0.693061
# 	[test eval] category 2 AUCROC: 0.719558
# 	[test eval] category 3 AUCROC: 0.674473
# iter: 5000, lr: 0.00050, loss: 6065.32177734375
# 	[train eval] category 0 AUCROC: 0.873232
# 	[train eval] category 1 AUCROC: 0.679644
# 	[train eval] category 2 AUCROC: 0.693407
# 	[train eval] category 3 AUCROC: 0.700573
# 	[test eval] category 0 AUCROC: 0.907449
# 	[test eval] category 1 AUCROC: 0.702942
# 	[test eval] category 2 AUCROC: 0.716241
# 	[test eval] category 3 AUCROC: 0.688282
# iter: 6000, lr: 0.00035, loss: 5980.79541015625
# 	[train eval] category 0 AUCROC: 0.882851
# 	[train eval] category 1 AUCROC: 0.692070
# 	[train eval] category 2 AUCROC: 0.695501
# 	[train eval] category 3 AUCROC: 0.708914
# 	[test eval] category 0 AUCROC: 0.910408
# 	[test eval] category 1 AUCROC: 0.705884
# 	[test eval] category 2 AUCROC: 0.716837
# 	[test eval] category 3 AUCROC: 0.696565
# iter: 7000, lr: 0.00021, loss: 5988.95458984375
# 	[train eval] category 0 AUCROC: 0.888407
# 	[train eval] category 1 AUCROC: 0.700083
# 	[train eval] category 2 AUCROC: 0.696998
# 	[train eval] category 3 AUCROC: 0.714112
# 	[test eval] category 0 AUCROC: 0.913044
# 	[test eval] category 1 AUCROC: 0.710340
# 	[test eval] category 2 AUCROC: 0.718861
# 	[test eval] category 3 AUCROC: 0.696207
# iter: 8000, lr: 0.00010, loss: 5940.103515625
# 	[train eval] category 0 AUCROC: 0.891061
# 	[train eval] category 1 AUCROC: 0.704844
# 	[train eval] category 2 AUCROC: 0.697435
# 	[train eval] category 3 AUCROC: 0.717284
# 	[test eval] category 0 AUCROC: 0.914184
# 	[test eval] category 1 AUCROC: 0.710663
# 	[test eval] category 2 AUCROC: 0.718997
# 	[test eval] category 3 AUCROC: 0.696224
# iter: 9000, lr: 0.00002, loss: 5939.43359375
# 	[train eval] category 0 AUCROC: 0.892296
# 	[train eval] category 1 AUCROC: 0.706585
# 	[train eval] category 2 AUCROC: 0.697580
# 	[train eval] category 3 AUCROC: 0.718428
# 	[test eval] category 0 AUCROC: 0.914898
# 	[test eval] category 1 AUCROC: 0.711616
# 	[test eval] category 2 AUCROC: 0.719099
# 	[test eval] category 3 AUCROC: 0.697245
# iter: 10000, lr: 0.00000, loss: 5938.60986328125
# 	[train eval] category 0 AUCROC: 0.892446
# 	[train eval] category 1 AUCROC: 0.706876
# 	[train eval] category 2 AUCROC: 0.697622
# 	[train eval] category 3 AUCROC: 0.718711
# 	[test eval] category 0 AUCROC: 0.915102
# 	[test eval] category 1 AUCROC: 0.711973
# 	[test eval] category 2 AUCROC: 0.719116
# 	[test eval] category 3 AUCROC: 0.696939
# Running GP for pre_cell_type, type = categorical, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4510.638671875
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3197.701904296875
# 	[train eval] category 0 AUCROC: 0.760949
# 	[train eval] category 1 AUCROC: 0.760949
# 	[test eval] category 0 AUCROC: 0.741366
# 	[test eval] category 1 AUCROC: 0.741366
# iter: 2000, lr: 0.00090, loss: 2945.154296875
# 	[train eval] category 0 AUCROC: 0.796217
# 	[train eval] category 1 AUCROC: 0.796217
# 	[test eval] category 0 AUCROC: 0.771761
# 	[test eval] category 1 AUCROC: 0.771761
# iter: 3000, lr: 0.00079, loss: 2800.139404296875
# 	[train eval] category 0 AUCROC: 0.821692
# 	[train eval] category 1 AUCROC: 0.821692
# 	[test eval] category 0 AUCROC: 0.789149
# 	[test eval] category 1 AUCROC: 0.789149
# iter: 4000, lr: 0.00065, loss: 2697.3974609375
# 	[train eval] category 0 AUCROC: 0.837833
# 	[train eval] category 1 AUCROC: 0.837833
# 	[test eval] category 0 AUCROC: 0.802700
# 	[test eval] category 1 AUCROC: 0.802700
# iter: 5000, lr: 0.00050, loss: 2634.219482421875
# 	[train eval] category 0 AUCROC: 0.845632
# 	[train eval] category 1 AUCROC: 0.845632
# 	[test eval] category 0 AUCROC: 0.805537
# 	[test eval] category 1 AUCROC: 0.805537
# iter: 6000, lr: 0.00035, loss: 2615.091552734375
# 	[train eval] category 0 AUCROC: 0.850538
# 	[train eval] category 1 AUCROC: 0.850538
# 	[test eval] category 0 AUCROC: 0.809134
# 	[test eval] category 1 AUCROC: 0.809134
# iter: 7000, lr: 0.00021, loss: 2574.227294921875
# 	[train eval] category 0 AUCROC: 0.853829
# 	[train eval] category 1 AUCROC: 0.853829
# 	[test eval] category 0 AUCROC: 0.810109
# 	[test eval] category 1 AUCROC: 0.810109
# iter: 8000, lr: 0.00010, loss: 2580.39501953125
# 	[train eval] category 0 AUCROC: 0.855590
# 	[train eval] category 1 AUCROC: 0.855590
# 	[test eval] category 0 AUCROC: 0.811147
# 	[test eval] category 1 AUCROC: 0.811147
# iter: 9000, lr: 0.00002, loss: 2548.6875
# 	[train eval] category 0 AUCROC: 0.856217
# 	[train eval] category 1 AUCROC: 0.856217
# 	[test eval] category 0 AUCROC: 0.811439
# 	[test eval] category 1 AUCROC: 0.811439
# iter: 10000, lr: 0.00000, loss: 2563.74267578125
# 	[train eval] category 0 AUCROC: 0.856351
# 	[train eval] category 1 AUCROC: 0.856351
# 	[test eval] category 0 AUCROC: 0.811527
# 	[test eval] category 1 AUCROC: 0.811527
# Running GP for post_cell_type, type = categorical, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4546.89892578125
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3477.63720703125
# 	[train eval] category 0 AUCROC: 0.662502
# 	[train eval] category 1 AUCROC: 0.662502
# 	[test eval] category 0 AUCROC: 0.697661
# 	[test eval] category 1 AUCROC: 0.697661
# iter: 2000, lr: 0.00090, loss: 3306.453125
# 	[train eval] category 0 AUCROC: 0.681327
# 	[train eval] category 1 AUCROC: 0.681327
# 	[test eval] category 0 AUCROC: 0.706349
# 	[test eval] category 1 AUCROC: 0.706349
# iter: 3000, lr: 0.00079, loss: 3276.36572265625
# 	[train eval] category 0 AUCROC: 0.691659
# 	[train eval] category 1 AUCROC: 0.691660
# 	[test eval] category 0 AUCROC: 0.714758
# 	[test eval] category 1 AUCROC: 0.714758
# iter: 4000, lr: 0.00065, loss: 3253.62158203125
# 	[train eval] category 0 AUCROC: 0.697718
# 	[train eval] category 1 AUCROC: 0.697718
# 	[test eval] category 0 AUCROC: 0.719646
# 	[test eval] category 1 AUCROC: 0.719646
# iter: 5000, lr: 0.00050, loss: 3237.00244140625
# 	[train eval] category 0 AUCROC: 0.703371
# 	[train eval] category 1 AUCROC: 0.703371
# 	[test eval] category 0 AUCROC: 0.724130
# 	[test eval] category 1 AUCROC: 0.724130
# iter: 6000, lr: 0.00035, loss: 3225.0634765625
# 	[train eval] category 0 AUCROC: 0.708625
# 	[train eval] category 1 AUCROC: 0.708625
# 	[test eval] category 0 AUCROC: 0.729259
# 	[test eval] category 1 AUCROC: 0.729259
# iter: 7000, lr: 0.00021, loss: 3201.86865234375
# 	[train eval] category 0 AUCROC: 0.712564
# 	[train eval] category 1 AUCROC: 0.712564
# 	[test eval] category 0 AUCROC: 0.733007
# 	[test eval] category 1 AUCROC: 0.733007
# iter: 8000, lr: 0.00010, loss: 3219.7470703125
# 	[train eval] category 0 AUCROC: 0.715254
# 	[train eval] category 1 AUCROC: 0.715254
# 	[test eval] category 0 AUCROC: 0.734970
# 	[test eval] category 1 AUCROC: 0.734970
# iter: 9000, lr: 0.00002, loss: 3218.609619140625
# 	[train eval] category 0 AUCROC: 0.716510
# 	[train eval] category 1 AUCROC: 0.716510
# 	[test eval] category 0 AUCROC: 0.735819
# 	[test eval] category 1 AUCROC: 0.735819
# iter: 10000, lr: 0.00000, loss: 3231.9970703125
# 	[train eval] category 0 AUCROC: 0.716739
# 	[train eval] category 1 AUCROC: 0.716739
# 	[test eval] category 0 AUCROC: 0.736110
# 	[test eval] category 1 AUCROC: 0.736110
# Running GP for has_mito_pre, type = categorical, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4673.126953125
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3324.793212890625
# 	[train eval] category 0 AUCROC: 0.727887
# 	[train eval] category 1 AUCROC: 0.727887
# 	[test eval] category 0 AUCROC: 0.686630
# 	[test eval] category 1 AUCROC: 0.686630
# iter: 2000, lr: 0.00090, loss: 3058.103271484375
# 	[train eval] category 0 AUCROC: 0.763603
# 	[train eval] category 1 AUCROC: 0.763603
# 	[test eval] category 0 AUCROC: 0.725611
# 	[test eval] category 1 AUCROC: 0.725611
# iter: 3000, lr: 0.00079, loss: 2967.0146484375
# 	[train eval] category 0 AUCROC: 0.782572
# 	[train eval] category 1 AUCROC: 0.782572
# 	[test eval] category 0 AUCROC: 0.748458
# 	[test eval] category 1 AUCROC: 0.748458
# iter: 4000, lr: 0.00065, loss: 2894.76318359375
# 	[train eval] category 0 AUCROC: 0.795056
# 	[train eval] category 1 AUCROC: 0.795056
# 	[test eval] category 0 AUCROC: 0.762174
# 	[test eval] category 1 AUCROC: 0.762174
# iter: 5000, lr: 0.00050, loss: 2887.03076171875
# 	[train eval] category 0 AUCROC: 0.803216
# 	[train eval] category 1 AUCROC: 0.803216
# 	[test eval] category 0 AUCROC: 0.770292
# 	[test eval] category 1 AUCROC: 0.770292
# iter: 6000, lr: 0.00035, loss: 2844.82763671875
# 	[train eval] category 0 AUCROC: 0.808667
# 	[train eval] category 1 AUCROC: 0.808667
# 	[test eval] category 0 AUCROC: 0.775180
# 	[test eval] category 1 AUCROC: 0.775180
# iter: 7000, lr: 0.00021, loss: 2853.7353515625
# 	[train eval] category 0 AUCROC: 0.812603
# 	[train eval] category 1 AUCROC: 0.812603
# 	[test eval] category 0 AUCROC: 0.777650
# 	[test eval] category 1 AUCROC: 0.777650
# iter: 8000, lr: 0.00010, loss: 2828.634765625
# 	[train eval] category 0 AUCROC: 0.814412
# 	[train eval] category 1 AUCROC: 0.814412
# 	[test eval] category 0 AUCROC: 0.778498
# 	[test eval] category 1 AUCROC: 0.778498
# iter: 9000, lr: 0.00002, loss: 2845.073486328125
# 	[train eval] category 0 AUCROC: 0.815328
# 	[train eval] category 1 AUCROC: 0.815328
# 	[test eval] category 0 AUCROC: 0.778777
# 	[test eval] category 1 AUCROC: 0.778777
# iter: 10000, lr: 0.00000, loss: 2829.957763671875
# 	[train eval] category 0 AUCROC: 0.815433
# 	[train eval] category 1 AUCROC: 0.815433
# 	[test eval] category 0 AUCROC: 0.778929
# 	[test eval] category 1 AUCROC: 0.778929
# Running GP for has_mito_post, type = categorical, fold = 0, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4548.060546875
# 	[train eval] category 0 AUCROC: 0.500395
# 	[train eval] category 1 AUCROC: 0.500395
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3239.4296875
# 	[train eval] category 0 AUCROC: 0.735588
# 	[train eval] category 1 AUCROC: 0.735588
# 	[test eval] category 0 AUCROC: 0.739935
# 	[test eval] category 1 AUCROC: 0.739935
# iter: 2000, lr: 0.00090, loss: 3102.250732421875
# 	[train eval] category 0 AUCROC: 0.758598
# 	[train eval] category 1 AUCROC: 0.758598
# 	[test eval] category 0 AUCROC: 0.755348
# 	[test eval] category 1 AUCROC: 0.755348
# iter: 3000, lr: 0.00079, loss: 3015.306640625
# 	[train eval] category 0 AUCROC: 0.771760
# 	[train eval] category 1 AUCROC: 0.771760
# 	[test eval] category 0 AUCROC: 0.766366
# 	[test eval] category 1 AUCROC: 0.766366
# iter: 4000, lr: 0.00065, loss: 2976.606689453125
# 	[train eval] category 0 AUCROC: 0.782958
# 	[train eval] category 1 AUCROC: 0.782958
# 	[test eval] category 0 AUCROC: 0.774243
# 	[test eval] category 1 AUCROC: 0.774243
# iter: 5000, lr: 0.00050, loss: 2951.021728515625
# 	[train eval] category 0 AUCROC: 0.790698
# 	[train eval] category 1 AUCROC: 0.790698
# 	[test eval] category 0 AUCROC: 0.778612
# 	[test eval] category 1 AUCROC: 0.778612
# iter: 6000, lr: 0.00035, loss: 2914.013671875
# 	[train eval] category 0 AUCROC: 0.796700
# 	[train eval] category 1 AUCROC: 0.796700
# 	[test eval] category 0 AUCROC: 0.782158
# 	[test eval] category 1 AUCROC: 0.782158
# iter: 7000, lr: 0.00021, loss: 2936.648681640625
# 	[train eval] category 0 AUCROC: 0.801055
# 	[train eval] category 1 AUCROC: 0.801055
# 	[test eval] category 0 AUCROC: 0.785134
# 	[test eval] category 1 AUCROC: 0.785134
# iter: 8000, lr: 0.00010, loss: 2928.93603515625
# 	[train eval] category 0 AUCROC: 0.803134
# 	[train eval] category 1 AUCROC: 0.803134
# 	[test eval] category 0 AUCROC: 0.786502
# 	[test eval] category 1 AUCROC: 0.786502
# iter: 9000, lr: 0.00002, loss: 2899.185791015625
# 	[train eval] category 0 AUCROC: 0.803995
# 	[train eval] category 1 AUCROC: 0.803995
# 	[test eval] category 0 AUCROC: 0.787034
# 	[test eval] category 1 AUCROC: 0.787034
# iter: 10000, lr: 0.00000, loss: 2879.920166015625
# 	[train eval] category 0 AUCROC: 0.804113
# 	[train eval] category 1 AUCROC: 0.804113
# 	[test eval] category 0 AUCROC: 0.786920
# 	[test eval] category 1 AUCROC: 0.786920
# Running GP for cleft_size_log1p_zscore, type = continuous, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7348.69921875
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6667.5927734375
# 	[train eval] explained variance: 0.157754
# 	[test eval] explained variance: 0.141125
# iter: 2000, lr: 0.00090, loss: 6444.70458984375
# 	[train eval] explained variance: 0.205383
# 	[test eval] explained variance: 0.188526
# iter: 3000, lr: 0.00079, loss: 6310.89794921875
# 	[train eval] explained variance: 0.247350
# 	[test eval] explained variance: 0.230962
# iter: 4000, lr: 0.00065, loss: 6148.80908203125
# 	[train eval] explained variance: 0.290863
# 	[test eval] explained variance: 0.273363
# iter: 5000, lr: 0.00050, loss: 5956.62353515625
# 	[train eval] explained variance: 0.334255
# 	[test eval] explained variance: 0.320436
# iter: 6000, lr: 0.00035, loss: 5836.85888671875
# 	[train eval] explained variance: 0.360112
# 	[test eval] explained variance: 0.349594
# iter: 7000, lr: 0.00021, loss: 5773.6982421875
# 	[train eval] explained variance: 0.372864
# 	[test eval] explained variance: 0.363499
# iter: 8000, lr: 0.00010, loss: 5743.5361328125
# 	[train eval] explained variance: 0.378844
# 	[test eval] explained variance: 0.369815
# iter: 9000, lr: 0.00002, loss: 5732.87890625
# 	[train eval] explained variance: 0.381013
# 	[test eval] explained variance: 0.371809
# iter: 10000, lr: 0.00000, loss: 5731.11767578125
# 	[train eval] explained variance: 0.381251
# 	[test eval] explained variance: 0.372180
# Running GP for presyn_soma_dist_log1p_zscore, type = continuous, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7238.7392578125
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6777.6591796875
# 	[train eval] explained variance: 0.018526
# 	[test eval] explained variance: -0.001455
# iter: 2000, lr: 0.00090, loss: 6704.28857421875
# 	[train eval] explained variance: 0.027890
# 	[test eval] explained variance: 0.004799
# iter: 3000, lr: 0.00079, loss: 6648.56884765625
# 	[train eval] explained variance: 0.035421
# 	[test eval] explained variance: 0.010446
# iter: 4000, lr: 0.00065, loss: 6598.20947265625
# 	[train eval] explained variance: 0.041270
# 	[test eval] explained variance: 0.013740
# iter: 5000, lr: 0.00050, loss: 6546.13037109375
# 	[train eval] explained variance: 0.046878
# 	[test eval] explained variance: 0.018043
# iter: 6000, lr: 0.00035, loss: 6505.6337890625
# 	[train eval] explained variance: 0.051368
# 	[test eval] explained variance: 0.019174
# iter: 7000, lr: 0.00021, loss: 6478.16845703125
# 	[train eval] explained variance: 0.054508
# 	[test eval] explained variance: 0.017495
# iter: 8000, lr: 0.00010, loss: 6463.8115234375
# 	[train eval] explained variance: 0.056078
# 	[test eval] explained variance: 0.018255
# iter: 9000, lr: 0.00002, loss: 6458.51318359375
# 	[train eval] explained variance: 0.056645
# 	[test eval] explained variance: 0.018706
# iter: 10000, lr: 0.00000, loss: 6457.4150390625
# 	[train eval] explained variance: 0.056754
# 	[test eval] explained variance: 0.018929
# Running GP for postsyn_soma_dist_log1p_zscore, type = continuous, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7348.6826171875
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6252.9345703125
# 	[train eval] explained variance: 0.214751
# 	[test eval] explained variance: 0.176468
# iter: 2000, lr: 0.00090, loss: 5891.134765625
# 	[train eval] explained variance: 0.312292
# 	[test eval] explained variance: 0.263836
# iter: 3000, lr: 0.00079, loss: 5655.09521484375
# 	[train eval] explained variance: 0.391713
# 	[test eval] explained variance: 0.338626
# iter: 4000, lr: 0.00065, loss: 5486.0234375
# 	[train eval] explained variance: 0.435794
# 	[test eval] explained variance: 0.381993
# iter: 5000, lr: 0.00050, loss: 5381.046875
# 	[train eval] explained variance: 0.459535
# 	[test eval] explained variance: 0.403648
# iter: 6000, lr: 0.00035, loss: 5317.427734375
# 	[train eval] explained variance: 0.472994
# 	[test eval] explained variance: 0.414926
# iter: 7000, lr: 0.00021, loss: 5282.16552734375
# 	[train eval] explained variance: 0.480245
# 	[test eval] explained variance: 0.420839
# iter: 8000, lr: 0.00010, loss: 5264.08544921875
# 	[train eval] explained variance: 0.483787
# 	[test eval] explained variance: 0.423450
# iter: 9000, lr: 0.00002, loss: 5257.31005859375
# 	[train eval] explained variance: 0.485207
# 	[test eval] explained variance: 0.424612
# iter: 10000, lr: 0.00000, loss: 5256.30810546875
# 	[train eval] explained variance: 0.485392
# 	[test eval] explained variance: 0.424749
# Running GP for mito_size_pre_vx_log1p_zscore_zi, type = continuous, fold = 1, control = has_mito_pre
# Number of training data points: 3169
# Number of test data points: 348
# iter: 0, lr: 0.00100, loss: 4610.29833984375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 4348.58349609375
# 	[train eval] explained variance: 0.098775
# 	[test eval] explained variance: 0.095331
# iter: 2000, lr: 0.00090, loss: 4322.30859375
# 	[train eval] explained variance: 0.120525
# 	[test eval] explained variance: 0.111024
# iter: 3000, lr: 0.00079, loss: 4309.32861328125
# 	[train eval] explained variance: 0.133962
# 	[test eval] explained variance: 0.118208
# iter: 4000, lr: 0.00065, loss: 4302.31689453125
# 	[train eval] explained variance: 0.142182
# 	[test eval] explained variance: 0.121684
# iter: 5000, lr: 0.00050, loss: 4298.49072265625
# 	[train eval] explained variance: 0.147852
# 	[test eval] explained variance: 0.123944
# iter: 6000, lr: 0.00035, loss: 4296.44873046875
# 	[train eval] explained variance: 0.151948
# 	[test eval] explained variance: 0.125613
# iter: 7000, lr: 0.00021, loss: 4295.3740234375
# 	[train eval] explained variance: 0.154939
# 	[test eval] explained variance: 0.126853
# iter: 8000, lr: 0.00010, loss: 4294.84033203125
# 	[train eval] explained variance: 0.156946
# 	[test eval] explained variance: 0.127701
# iter: 9000, lr: 0.00002, loss: 4294.63525390625
# 	[train eval] explained variance: 0.157883
# 	[test eval] explained variance: 0.128060
# iter: 10000, lr: 0.00000, loss: 4294.59423828125
# 	[train eval] explained variance: 0.158027
# 	[test eval] explained variance: 0.128093
# Running GP for mito_size_post_vx_log1p_zscore_zi, type = continuous, fold = 1, control = has_mito_post
# Number of training data points: 3533
# Number of test data points: 396
# iter: 0, lr: 0.00100, loss: 5127.4423828125
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 4907.2060546875
# 	[train eval] explained variance: 0.018312
# 	[test eval] explained variance: 0.020453
# iter: 2000, lr: 0.00090, loss: 4846.60498046875
# 	[train eval] explained variance: 0.026274
# 	[test eval] explained variance: 0.016635
# iter: 3000, lr: 0.00079, loss: 4814.94677734375
# 	[train eval] explained variance: 0.036213
# 	[test eval] explained variance: 0.019725
# iter: 4000, lr: 0.00065, loss: 4797.5361328125
# 	[train eval] explained variance: 0.043458
# 	[test eval] explained variance: 0.021463
# iter: 5000, lr: 0.00050, loss: 4787.7890625
# 	[train eval] explained variance: 0.048413
# 	[test eval] explained variance: 0.022488
# iter: 6000, lr: 0.00035, loss: 4782.255859375
# 	[train eval] explained variance: 0.051842
# 	[test eval] explained variance: 0.022967
# iter: 7000, lr: 0.00021, loss: 4779.19873046875
# 	[train eval] explained variance: 0.054006
# 	[test eval] explained variance: 0.023105
# iter: 8000, lr: 0.00010, loss: 4777.5947265625
# 	[train eval] explained variance: 0.055254
# 	[test eval] explained variance: 0.023302
# iter: 9000, lr: 0.00002, loss: 4776.90869140625
# 	[train eval] explained variance: 0.055712
# 	[test eval] explained variance: 0.023300
# iter: 10000, lr: 0.00000, loss: 4776.84716796875
# 	[train eval] explained variance: 0.055806
# 	[test eval] explained variance: 0.023402
# Running GP for pre_and_post_cell_types, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 560
# iter: 0, lr: 0.00100, loss: 8656.3125
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[train eval] category 2 AUCROC: 0.500000
# 	[train eval] category 3 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# 	[test eval] category 2 AUCROC: 0.500000
# 	[test eval] category 3 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 6561.353515625
# 	[train eval] category 0 AUCROC: 0.840730
# 	[train eval] category 1 AUCROC: 0.631453
# 	[train eval] category 2 AUCROC: 0.615938
# 	[train eval] category 3 AUCROC: 0.641972
# 	[test eval] category 0 AUCROC: 0.771752
# 	[test eval] category 1 AUCROC: 0.627993
# 	[test eval] category 2 AUCROC: 0.526497
# 	[test eval] category 3 AUCROC: 0.657789
# iter: 2000, lr: 0.00090, loss: 6150.0
# 	[train eval] category 0 AUCROC: 0.864553
# 	[train eval] category 1 AUCROC: 0.665251
# 	[train eval] category 2 AUCROC: 0.687278
# 	[train eval] category 3 AUCROC: 0.675851
# 	[test eval] category 0 AUCROC: 0.808656
# 	[test eval] category 1 AUCROC: 0.645935
# 	[test eval] category 2 AUCROC: 0.616327
# 	[test eval] category 3 AUCROC: 0.681480
# iter: 3000, lr: 0.00079, loss: 6059.87646484375
# 	[train eval] category 0 AUCROC: 0.875201
# 	[train eval] category 1 AUCROC: 0.674947
# 	[train eval] category 2 AUCROC: 0.695425
# 	[train eval] category 3 AUCROC: 0.683534
# 	[test eval] category 0 AUCROC: 0.823912
# 	[test eval] category 1 AUCROC: 0.656412
# 	[test eval] category 2 AUCROC: 0.651735
# 	[test eval] category 3 AUCROC: 0.701769
# iter: 4000, lr: 0.00065, loss: 5974.96630859375
# 	[train eval] category 0 AUCROC: 0.886687
# 	[train eval] category 1 AUCROC: 0.686561
# 	[train eval] category 2 AUCROC: 0.699575
# 	[train eval] category 3 AUCROC: 0.692149
# 	[test eval] category 0 AUCROC: 0.838537
# 	[test eval] category 1 AUCROC: 0.666565
# 	[test eval] category 2 AUCROC: 0.673588
# 	[test eval] category 3 AUCROC: 0.717160
# iter: 5000, lr: 0.00050, loss: 5875.72314453125
# 	[train eval] category 0 AUCROC: 0.896546
# 	[train eval] category 1 AUCROC: 0.699602
# 	[train eval] category 2 AUCROC: 0.702050
# 	[train eval] category 3 AUCROC: 0.700981
# 	[test eval] category 0 AUCROC: 0.856224
# 	[test eval] category 1 AUCROC: 0.677483
# 	[test eval] category 2 AUCROC: 0.691922
# 	[test eval] category 3 AUCROC: 0.727007
# iter: 6000, lr: 0.00035, loss: 5858.552734375
# 	[train eval] category 0 AUCROC: 0.903072
# 	[train eval] category 1 AUCROC: 0.711079
# 	[train eval] category 2 AUCROC: 0.703645
# 	[train eval] category 3 AUCROC: 0.707695
# 	[test eval] category 0 AUCROC: 0.866803
# 	[test eval] category 1 AUCROC: 0.686003
# 	[test eval] category 2 AUCROC: 0.700867
# 	[test eval] category 3 AUCROC: 0.734065
# iter: 7000, lr: 0.00021, loss: 5815.0009765625
# 	[train eval] category 0 AUCROC: 0.906676
# 	[train eval] category 1 AUCROC: 0.718449
# 	[train eval] category 2 AUCROC: 0.704264
# 	[train eval] category 3 AUCROC: 0.712819
# 	[test eval] category 0 AUCROC: 0.872806
# 	[test eval] category 1 AUCROC: 0.691327
# 	[test eval] category 2 AUCROC: 0.706939
# 	[test eval] category 3 AUCROC: 0.733537
# iter: 8000, lr: 0.00010, loss: 5795.8515625
# 	[train eval] category 0 AUCROC: 0.908736
# 	[train eval] category 1 AUCROC: 0.722923
# 	[train eval] category 2 AUCROC: 0.704653
# 	[train eval] category 3 AUCROC: 0.715721
# 	[test eval] category 0 AUCROC: 0.875595
# 	[test eval] category 1 AUCROC: 0.693384
# 	[test eval] category 2 AUCROC: 0.709439
# 	[test eval] category 3 AUCROC: 0.733690
# iter: 9000, lr: 0.00002, loss: 5791.94287109375
# 	[train eval] category 0 AUCROC: 0.909522
# 	[train eval] category 1 AUCROC: 0.724635
# 	[train eval] category 2 AUCROC: 0.704803
# 	[train eval] category 3 AUCROC: 0.716812
# 	[test eval] category 0 AUCROC: 0.876514
# 	[test eval] category 1 AUCROC: 0.693912
# 	[test eval] category 2 AUCROC: 0.710425
# 	[test eval] category 3 AUCROC: 0.733435
# iter: 10000, lr: 0.00000, loss: 5799.91357421875
# 	[train eval] category 0 AUCROC: 0.909669
# 	[train eval] category 1 AUCROC: 0.725050
# 	[train eval] category 2 AUCROC: 0.704884
# 	[train eval] category 3 AUCROC: 0.716946
# 	[test eval] category 0 AUCROC: 0.876803
# 	[test eval] category 1 AUCROC: 0.694048
# 	[test eval] category 2 AUCROC: 0.710969
# 	[test eval] category 3 AUCROC: 0.734031
# Running GP for pre_cell_type, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4658.28564453125
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3210.210693359375
# 	[train eval] category 0 AUCROC: 0.767765
# 	[train eval] category 1 AUCROC: 0.767765
# 	[test eval] category 0 AUCROC: 0.786717
# 	[test eval] category 1 AUCROC: 0.786717
# iter: 2000, lr: 0.00090, loss: 2934.564453125
# 	[train eval] category 0 AUCROC: 0.798190
# 	[train eval] category 1 AUCROC: 0.798190
# 	[test eval] category 0 AUCROC: 0.824483
# 	[test eval] category 1 AUCROC: 0.824483
# iter: 3000, lr: 0.00079, loss: 2810.872314453125
# 	[train eval] category 0 AUCROC: 0.820055
# 	[train eval] category 1 AUCROC: 0.820055
# 	[test eval] category 0 AUCROC: 0.844822
# 	[test eval] category 1 AUCROC: 0.844822
# iter: 4000, lr: 0.00065, loss: 2674.596435546875
# 	[train eval] category 0 AUCROC: 0.834122
# 	[train eval] category 1 AUCROC: 0.834122
# 	[test eval] category 0 AUCROC: 0.850673
# 	[test eval] category 1 AUCROC: 0.850673
# iter: 5000, lr: 0.00050, loss: 2640.48681640625
# 	[train eval] category 0 AUCROC: 0.843038
# 	[train eval] category 1 AUCROC: 0.843038
# 	[test eval] category 0 AUCROC: 0.856068
# 	[test eval] category 1 AUCROC: 0.856068
# iter: 6000, lr: 0.00035, loss: 2617.031005859375
# 	[train eval] category 0 AUCROC: 0.848406
# 	[train eval] category 1 AUCROC: 0.848406
# 	[test eval] category 0 AUCROC: 0.859158
# 	[test eval] category 1 AUCROC: 0.859158
# iter: 7000, lr: 0.00021, loss: 2610.2919921875
# 	[train eval] category 0 AUCROC: 0.851377
# 	[train eval] category 1 AUCROC: 0.851377
# 	[test eval] category 0 AUCROC: 0.860133
# 	[test eval] category 1 AUCROC: 0.860133
# iter: 8000, lr: 0.00010, loss: 2582.3662109375
# 	[train eval] category 0 AUCROC: 0.853109
# 	[train eval] category 1 AUCROC: 0.853109
# 	[test eval] category 0 AUCROC: 0.860323
# 	[test eval] category 1 AUCROC: 0.860323
# iter: 9000, lr: 0.00002, loss: 2618.935791015625
# 	[train eval] category 0 AUCROC: 0.853974
# 	[train eval] category 1 AUCROC: 0.853974
# 	[test eval] category 0 AUCROC: 0.860665
# 	[test eval] category 1 AUCROC: 0.860665
# iter: 10000, lr: 0.00000, loss: 2590.576904296875
# 	[train eval] category 0 AUCROC: 0.854079
# 	[train eval] category 1 AUCROC: 0.854079
# 	[test eval] category 0 AUCROC: 0.860678
# 	[test eval] category 1 AUCROC: 0.860678
# Running GP for post_cell_type, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4590.81591796875
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3458.963623046875
# 	[train eval] category 0 AUCROC: 0.665180
# 	[train eval] category 1 AUCROC: 0.665180
# 	[test eval] category 0 AUCROC: 0.651904
# 	[test eval] category 1 AUCROC: 0.651904
# iter: 2000, lr: 0.00090, loss: 3287.50341796875
# 	[train eval] category 0 AUCROC: 0.674816
# 	[train eval] category 1 AUCROC: 0.674816
# 	[test eval] category 0 AUCROC: 0.656375
# 	[test eval] category 1 AUCROC: 0.656375
# iter: 3000, lr: 0.00079, loss: 3265.552978515625
# 	[train eval] category 0 AUCROC: 0.681460
# 	[train eval] category 1 AUCROC: 0.681460
# 	[test eval] category 0 AUCROC: 0.658553
# 	[test eval] category 1 AUCROC: 0.658553
# iter: 4000, lr: 0.00065, loss: 3239.804931640625
# 	[train eval] category 0 AUCROC: 0.686814
# 	[train eval] category 1 AUCROC: 0.686814
# 	[test eval] category 0 AUCROC: 0.663049
# 	[test eval] category 1 AUCROC: 0.663049
# iter: 5000, lr: 0.00050, loss: 3237.54052734375
# 	[train eval] category 0 AUCROC: 0.691958
# 	[train eval] category 1 AUCROC: 0.691958
# 	[test eval] category 0 AUCROC: 0.669482
# 	[test eval] category 1 AUCROC: 0.669482
# iter: 6000, lr: 0.00035, loss: 3220.08056640625
# 	[train eval] category 0 AUCROC: 0.696992
# 	[train eval] category 1 AUCROC: 0.696992
# 	[test eval] category 0 AUCROC: 0.675739
# 	[test eval] category 1 AUCROC: 0.675739
# iter: 7000, lr: 0.00021, loss: 3220.979736328125
# 	[train eval] category 0 AUCROC: 0.701296
# 	[train eval] category 1 AUCROC: 0.701296
# 	[test eval] category 0 AUCROC: 0.681349
# 	[test eval] category 1 AUCROC: 0.681349
# iter: 8000, lr: 0.00010, loss: 3226.8037109375
# 	[train eval] category 0 AUCROC: 0.704253
# 	[train eval] category 1 AUCROC: 0.704253
# 	[test eval] category 0 AUCROC: 0.683350
# 	[test eval] category 1 AUCROC: 0.683350
# iter: 9000, lr: 0.00002, loss: 3229.89892578125
# 	[train eval] category 0 AUCROC: 0.705279
# 	[train eval] category 1 AUCROC: 0.705279
# 	[test eval] category 0 AUCROC: 0.685300
# 	[test eval] category 1 AUCROC: 0.685300
# iter: 10000, lr: 0.00000, loss: 3229.175048828125
# 	[train eval] category 0 AUCROC: 0.705523
# 	[train eval] category 1 AUCROC: 0.705523
# 	[test eval] category 0 AUCROC: 0.685098
# 	[test eval] category 1 AUCROC: 0.685098
# Running GP for has_mito_pre, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4560.27734375
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3242.1943359375
# 	[train eval] category 0 AUCROC: 0.740306
# 	[train eval] category 1 AUCROC: 0.740306
# 	[test eval] category 0 AUCROC: 0.702283
# 	[test eval] category 1 AUCROC: 0.702283
# iter: 2000, lr: 0.00090, loss: 3074.617431640625
# 	[train eval] category 0 AUCROC: 0.759843
# 	[train eval] category 1 AUCROC: 0.759843
# 	[test eval] category 0 AUCROC: 0.740606
# 	[test eval] category 1 AUCROC: 0.740606
# iter: 3000, lr: 0.00079, loss: 3004.99853515625
# 	[train eval] category 0 AUCROC: 0.776796
# 	[train eval] category 1 AUCROC: 0.776796
# 	[test eval] category 0 AUCROC: 0.772229
# 	[test eval] category 1 AUCROC: 0.772229
# iter: 4000, lr: 0.00065, loss: 2929.279541015625
# 	[train eval] category 0 AUCROC: 0.789920
# 	[train eval] category 1 AUCROC: 0.789920
# 	[test eval] category 0 AUCROC: 0.793214
# 	[test eval] category 1 AUCROC: 0.793214
# iter: 5000, lr: 0.00050, loss: 2909.396240234375
# 	[train eval] category 0 AUCROC: 0.798351
# 	[train eval] category 1 AUCROC: 0.798351
# 	[test eval] category 0 AUCROC: 0.803447
# 	[test eval] category 1 AUCROC: 0.803447
# iter: 6000, lr: 0.00035, loss: 2892.559326171875
# 	[train eval] category 0 AUCROC: 0.804403
# 	[train eval] category 1 AUCROC: 0.804404
# 	[test eval] category 0 AUCROC: 0.809628
# 	[test eval] category 1 AUCROC: 0.809628
# iter: 7000, lr: 0.00021, loss: 2872.8046875
# 	[train eval] category 0 AUCROC: 0.808121
# 	[train eval] category 1 AUCROC: 0.808121
# 	[test eval] category 0 AUCROC: 0.812122
# 	[test eval] category 1 AUCROC: 0.812122
# iter: 8000, lr: 0.00010, loss: 2884.0517578125
# 	[train eval] category 0 AUCROC: 0.810474
# 	[train eval] category 1 AUCROC: 0.810474
# 	[test eval] category 0 AUCROC: 0.813857
# 	[test eval] category 1 AUCROC: 0.813857
# iter: 9000, lr: 0.00002, loss: 2859.871337890625
# 	[train eval] category 0 AUCROC: 0.811127
# 	[train eval] category 1 AUCROC: 0.811127
# 	[test eval] category 0 AUCROC: 0.814339
# 	[test eval] category 1 AUCROC: 0.814339
# iter: 10000, lr: 0.00000, loss: 2866.289306640625
# 	[train eval] category 0 AUCROC: 0.811247
# 	[train eval] category 1 AUCROC: 0.811247
# 	[test eval] category 0 AUCROC: 0.814415
# 	[test eval] category 1 AUCROC: 0.814415
# Running GP for has_mito_post, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4584.587890625
# 	[train eval] category 0 AUCROC: 0.500000
# 	[train eval] category 1 AUCROC: 0.500000
# 	[test eval] category 0 AUCROC: 0.500000
# 	[test eval] category 1 AUCROC: 0.500000
# iter: 1000, lr: 0.00098, loss: 3349.7490234375
# 	[train eval] category 0 AUCROC: 0.726711
# 	[train eval] category 1 AUCROC: 0.726711
# 	[test eval] category 0 AUCROC: 0.749028
# 	[test eval] category 1 AUCROC: 0.749028
# iter: 2000, lr: 0.00090, loss: 3121.579345703125
# 	[train eval] category 0 AUCROC: 0.750867
# 	[train eval] category 1 AUCROC: 0.750867
# 	[test eval] category 0 AUCROC: 0.781082
# 	[test eval] category 1 AUCROC: 0.781082
# iter: 3000, lr: 0.00079, loss: 3074.4287109375
# 	[train eval] category 0 AUCROC: 0.766214
# 	[train eval] category 1 AUCROC: 0.766214
# 	[test eval] category 0 AUCROC: 0.786958
# 	[test eval] category 1 AUCROC: 0.786958
# iter: 4000, lr: 0.00065, loss: 3015.227783203125
# 	[train eval] category 0 AUCROC: 0.778230
# 	[train eval] category 1 AUCROC: 0.778230
# 	[test eval] category 0 AUCROC: 0.787946
# 	[test eval] category 1 AUCROC: 0.787946
# iter: 5000, lr: 0.00050, loss: 2976.5087890625
# 	[train eval] category 0 AUCROC: 0.786981
# 	[train eval] category 1 AUCROC: 0.786981
# 	[test eval] category 0 AUCROC: 0.788959
# 	[test eval] category 1 AUCROC: 0.788959
# iter: 6000, lr: 0.00035, loss: 2960.186279296875
# 	[train eval] category 0 AUCROC: 0.792998
# 	[train eval] category 1 AUCROC: 0.792998
# 	[test eval] category 0 AUCROC: 0.792391
# 	[test eval] category 1 AUCROC: 0.792391
# iter: 7000, lr: 0.00021, loss: 2932.607421875
# 	[train eval] category 0 AUCROC: 0.796934
# 	[train eval] category 1 AUCROC: 0.796934
# 	[test eval] category 0 AUCROC: 0.794557
# 	[test eval] category 1 AUCROC: 0.794557
# iter: 8000, lr: 0.00010, loss: 2937.610595703125
# 	[train eval] category 0 AUCROC: 0.799349
# 	[train eval] category 1 AUCROC: 0.799349
# 	[test eval] category 0 AUCROC: 0.795646
# 	[test eval] category 1 AUCROC: 0.795646
# iter: 9000, lr: 0.00002, loss: 2915.495849609375
# 	[train eval] category 0 AUCROC: 0.800213
# 	[train eval] category 1 AUCROC: 0.800213
# 	[test eval] category 0 AUCROC: 0.796634
# 	[test eval] category 1 AUCROC: 0.796634
# iter: 10000, lr: 0.00000, loss: 2946.337158203125
# 	[train eval] category 0 AUCROC: 0.800310
# 	[train eval] category 1 AUCROC: 0.800310
# 	[test eval] category 0 AUCROC: 0.796659
# 	[test eval] category 1 AUCROC: 0.796659
# Running GP for cleft_size_log1p_zscore, type = continuous, fold = 2, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7368.22509765625
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6778.974609375
# 	[train eval] explained variance: 0.139512
# 	[test eval] explained variance: 0.104331
# iter: 2000, lr: 0.00090, loss: 6586.92529296875
# 	[train eval] explained variance: 0.178566
# 	[test eval] explained variance: 0.138737
# iter: 3000, lr: 0.00079, loss: 6440.59326171875
# 	[train eval] explained variance: 0.221118
# 	[test eval] explained variance: 0.178088
# iter: 4000, lr: 0.00065, loss: 6196.611328125
# 	[train eval] explained variance: 0.293421
# 	[test eval] explained variance: 0.243971
# iter: 5000, lr: 0.00050, loss: 6005.17333984375
# 	[train eval] explained variance: 0.339926
# 	[test eval] explained variance: 0.288762
# iter: 6000, lr: 0.00035, loss: 5894.59765625
# 	[train eval] explained variance: 0.364525
# 	[test eval] explained variance: 0.312211
# iter: 7000, lr: 0.00021, loss: 5834.39306640625
# 	[train eval] explained variance: 0.376917
# 	[test eval] explained variance: 0.323956
# iter: 8000, lr: 0.00010, loss: 5804.4072265625
# 	[train eval] explained variance: 0.382862
# 	[test eval] explained variance: 0.328879
# iter: 9000, lr: 0.00002, loss: 5792.9345703125
# 	[train eval] explained variance: 0.385017
# 	[test eval] explained variance: 0.330552
# iter: 10000, lr: 0.00000, loss: 5791.41162109375
# 	[train eval] explained variance: 0.385268
# 	[test eval] explained variance: 0.331030
# Running GP for presyn_soma_dist_log1p_zscore, type = continuous, fold = 2, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7226.787109375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 6732.4326171875
# 	[train eval] explained variance: 0.016343
# 	[test eval] explained variance: -0.003149
# iter: 2000, lr: 0.00090, loss: 6635.40869140625
# ...
# iter: 9000, lr: 0.00002, loss: 4161.0830078125
# 	[train eval] category 0 AUCROC: 0.991044
# 	[train eval] category 1 AUCROC: 0.984451
# 	[train eval] category 2 AUCROC: 0.980191
# 	[train eval] category 3 AUCROC: 0.999743
# 	[test eval] category 0 AUCROC: 0.912347
# 	[test eval] category 1 AUCROC: 0.781156
# 	[test eval] category 2 AUCROC: 0.741190
# 	[test eval] category 3 AUCROC: 0.636395
# iter: 10000, lr: 0.00000, loss: 4182.22216796875
# 	[train eval] category 0 AUCROC: 0.991026
# 	[train eval] category 1 AUCROC: 0.984312
# 	[train eval] category 2 AUCROC: 0.979922
# 	[train eval] category 3 AUCROC: 0.999787
# 	[test eval] category 0 AUCROC: 0.912738
# 	[test eval] category 1 AUCROC: 0.777449
# 	[test eval] category 2 AUCROC: 0.740476
# 	[test eval] category 3 AUCROC: 0.635578
# Running GP for pre_cell_type, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4622.98046875
# 	[train eval] category 0 AUCROC: 0.708891
# 	[train eval] category 1 AUCROC: 0.714426
# 	[test eval] category 0 AUCROC: 0.698991
# 	[test eval] category 1 AUCROC: 0.706127
# iter: 1000, lr: 0.00098, loss: 2475.047119140625
# 	[train eval] category 0 AUCROC: 0.900836
# 	[train eval] category 1 AUCROC: 0.900836
# 	[test eval] category 0 AUCROC: 0.858766
# 	[test eval] category 1 AUCROC: 0.858766
# iter: 2000, lr: 0.00090, loss: 2419.734130859375
# 	[train eval] category 0 AUCROC: 0.921144
# 	[train eval] category 1 AUCROC: 0.921144
# 	[test eval] category 0 AUCROC: 0.862350
# 	[test eval] category 1 AUCROC: 0.862350
# iter: 3000, lr: 0.00079, loss: 2377.623046875
# 	[train eval] category 0 AUCROC: 0.935244
# 	[train eval] category 1 AUCROC: 0.935244
# 	[test eval] category 0 AUCROC: 0.865440
# 	[test eval] category 1 AUCROC: 0.865440
# iter: 4000, lr: 0.00065, loss: 2359.479248046875
# 	[train eval] category 0 AUCROC: 0.945660
# 	[train eval] category 1 AUCROC: 0.945660
# 	[test eval] category 0 AUCROC: 0.864034
# 	[test eval] category 1 AUCROC: 0.864034
# iter: 5000, lr: 0.00050, loss: 2361.191162109375
# 	[train eval] category 0 AUCROC: 0.950330
# 	[train eval] category 1 AUCROC: 0.950330
# 	[test eval] category 0 AUCROC: 0.866592
# 	[test eval] category 1 AUCROC: 0.866592
# iter: 6000, lr: 0.00035, loss: 2390.96923828125
# 	[train eval] category 0 AUCROC: 0.951778
# 	[train eval] category 1 AUCROC: 0.951778
# 	[test eval] category 0 AUCROC: 0.865491
# 	[test eval] category 1 AUCROC: 0.865491
# iter: 7000, lr: 0.00021, loss: 2338.68017578125
# 	[train eval] category 0 AUCROC: 0.953507
# 	[train eval] category 1 AUCROC: 0.953507
# 	[test eval] category 0 AUCROC: 0.865111
# 	[test eval] category 1 AUCROC: 0.865111
# iter: 8000, lr: 0.00010, loss: 2276.057373046875
# 	[train eval] category 0 AUCROC: 0.953797
# 	[train eval] category 1 AUCROC: 0.953797
# 	[test eval] category 0 AUCROC: 0.868340
# 	[test eval] category 1 AUCROC: 0.868340
# iter: 9000, lr: 0.00002, loss: 2309.154052734375
# 	[train eval] category 0 AUCROC: 0.954940
# 	[train eval] category 1 AUCROC: 0.954940
# 	[test eval] category 0 AUCROC: 0.866998
# 	[test eval] category 1 AUCROC: 0.866998
# iter: 10000, lr: 0.00000, loss: 2306.09423828125
# 	[train eval] category 0 AUCROC: 0.954971
# 	[train eval] category 1 AUCROC: 0.954971
# 	[test eval] category 0 AUCROC: 0.867897
# 	[test eval] category 1 AUCROC: 0.867897
# Running GP for post_cell_type, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4621.0029296875
# 	[train eval] category 0 AUCROC: 0.625796
# 	[train eval] category 1 AUCROC: 0.627980
# 	[test eval] category 0 AUCROC: 0.581021
# 	[test eval] category 1 AUCROC: 0.589120
# iter: 1000, lr: 0.00098, loss: 3039.616455078125
# 	[train eval] category 0 AUCROC: 0.874114
# 	[train eval] category 1 AUCROC: 0.874114
# 	[test eval] category 0 AUCROC: 0.765669
# 	[test eval] category 1 AUCROC: 0.765669
# iter: 2000, lr: 0.00090, loss: 2964.605224609375
# 	[train eval] category 0 AUCROC: 0.909233
# 	[train eval] category 1 AUCROC: 0.909233
# 	[test eval] category 0 AUCROC: 0.772888
# 	[test eval] category 1 AUCROC: 0.772888
# iter: 3000, lr: 0.00079, loss: 2936.925048828125
# 	[train eval] category 0 AUCROC: 0.933883
# 	[train eval] category 1 AUCROC: 0.933883
# 	[test eval] category 0 AUCROC: 0.775269
# 	[test eval] category 1 AUCROC: 0.775269
# iter: 4000, lr: 0.00065, loss: 2858.2412109375
# 	[train eval] category 0 AUCROC: 0.949294
# 	[train eval] category 1 AUCROC: 0.949294
# 	[test eval] category 0 AUCROC: 0.774623
# 	[test eval] category 1 AUCROC: 0.774623
# iter: 5000, lr: 0.00050, loss: 2883.322509765625
# 	[train eval] category 0 AUCROC: 0.956429
# 	[train eval] category 1 AUCROC: 0.956429
# 	[test eval] category 0 AUCROC: 0.779765
# 	[test eval] category 1 AUCROC: 0.779765
# iter: 6000, lr: 0.00035, loss: 2834.6337890625
# 	[train eval] category 0 AUCROC: 0.960486
# 	[train eval] category 1 AUCROC: 0.960486
# 	[test eval] category 0 AUCROC: 0.781246
# 	[test eval] category 1 AUCROC: 0.781246
# iter: 7000, lr: 0.00021, loss: 2833.31005859375
# 	[train eval] category 0 AUCROC: 0.962547
# 	[train eval] category 1 AUCROC: 0.962547
# 	[test eval] category 0 AUCROC: 0.776561
# 	[test eval] category 1 AUCROC: 0.776561
# iter: 8000, lr: 0.00010, loss: 2857.15185546875
# 	[train eval] category 0 AUCROC: 0.965048
# 	[train eval] category 1 AUCROC: 0.965048
# 	[test eval] category 0 AUCROC: 0.777308
# 	[test eval] category 1 AUCROC: 0.777308
# iter: 9000, lr: 0.00002, loss: 2804.93603515625
# 	[train eval] category 0 AUCROC: 0.965524
# 	[train eval] category 1 AUCROC: 0.965524
# 	[test eval] category 0 AUCROC: 0.777738
# 	[test eval] category 1 AUCROC: 0.777738
# iter: 10000, lr: 0.00000, loss: 2810.09375
# 	[train eval] category 0 AUCROC: 0.965819
# 	[train eval] category 1 AUCROC: 0.965819
# 	[test eval] category 0 AUCROC: 0.777789
# 	[test eval] category 1 AUCROC: 0.777789
# Running GP for has_mito_pre, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4589.52099609375
# 	[train eval] category 0 AUCROC: 0.691167
# 	[train eval] category 1 AUCROC: 0.697913
# 	[test eval] category 0 AUCROC: 0.653272
# 	[test eval] category 1 AUCROC: 0.652208
# iter: 1000, lr: 0.00098, loss: 2792.04541015625
# 	[train eval] category 0 AUCROC: 0.872710
# 	[train eval] category 1 AUCROC: 0.872710
# 	[test eval] category 0 AUCROC: 0.795393
# 	[test eval] category 1 AUCROC: 0.795393
# iter: 2000, lr: 0.00090, loss: 2747.34521484375
# 	[train eval] category 0 AUCROC: 0.892608
# 	[train eval] category 1 AUCROC: 0.892608
# 	[test eval] category 0 AUCROC: 0.800344
# 	[test eval] category 1 AUCROC: 0.800344
# iter: 3000, lr: 0.00079, loss: 2708.31396484375
# 	[train eval] category 0 AUCROC: 0.906346
# 	[train eval] category 1 AUCROC: 0.906346
# 	[test eval] category 0 AUCROC: 0.799230
# 	[test eval] category 1 AUCROC: 0.799230
# iter: 4000, lr: 0.00065, loss: 2669.209228515625
# 	[train eval] category 0 AUCROC: 0.918091
# 	[train eval] category 1 AUCROC: 0.918091
# 	[test eval] category 0 AUCROC: 0.799483
# 	[test eval] category 1 AUCROC: 0.799483
# iter: 5000, lr: 0.00050, loss: 2657.9921875
# 	[train eval] category 0 AUCROC: 0.924122
# 	[train eval] category 1 AUCROC: 0.924122
# 	[test eval] category 0 AUCROC: 0.801130
# 	[test eval] category 1 AUCROC: 0.801130
# iter: 6000, lr: 0.00035, loss: 2685.734619140625
# 	[train eval] category 0 AUCROC: 0.926451
# 	[train eval] category 1 AUCROC: 0.926451
# 	[test eval] category 0 AUCROC: 0.794164
# 	[test eval] category 1 AUCROC: 0.794164
# iter: 7000, lr: 0.00021, loss: 2665.162353515625
# 	[train eval] category 0 AUCROC: 0.927660
# 	[train eval] category 1 AUCROC: 0.927660
# 	[test eval] category 0 AUCROC: 0.799458
# 	[test eval] category 1 AUCROC: 0.799458
# iter: 8000, lr: 0.00010, loss: 2671.79833984375
# 	[train eval] category 0 AUCROC: 0.928444
# 	[train eval] category 1 AUCROC: 0.928444
# 	[test eval] category 0 AUCROC: 0.800294
# 	[test eval] category 1 AUCROC: 0.800294
# iter: 9000, lr: 0.00002, loss: 2683.6533203125
# 	[train eval] category 0 AUCROC: 0.928990
# 	[train eval] category 1 AUCROC: 0.928990
# 	[test eval] category 0 AUCROC: 0.798002
# 	[test eval] category 1 AUCROC: 0.798002
# iter: 10000, lr: 0.00000, loss: 2685.380126953125
# 	[train eval] category 0 AUCROC: 0.929192
# 	[train eval] category 1 AUCROC: 0.929192
# 	[test eval] category 0 AUCROC: 0.798799
# 	[test eval] category 1 AUCROC: 0.798799
# Running GP for has_mito_post, type = categorical, fold = 1, control = None
# Number of training data points: 5060
# Number of test data points: 562
# iter: 0, lr: 0.00100, loss: 4534.1669921875
# 	[train eval] category 0 AUCROC: 0.686193
# 	[train eval] category 1 AUCROC: 0.691846
# 	[test eval] category 0 AUCROC: 0.727270
# 	[test eval] category 1 AUCROC: 0.735629
# iter: 1000, lr: 0.00098, loss: 2881.78857421875
# 	[train eval] category 0 AUCROC: 0.860477
# 	[train eval] category 1 AUCROC: 0.860477
# 	[test eval] category 0 AUCROC: 0.794253
# 	[test eval] category 1 AUCROC: 0.794253
# iter: 2000, lr: 0.00090, loss: 2801.89013671875
# 	[train eval] category 0 AUCROC: 0.877089
# 	[train eval] category 1 AUCROC: 0.877089
# 	[test eval] category 0 AUCROC: 0.799889
# 	[test eval] category 1 AUCROC: 0.799889
# iter: 3000, lr: 0.00079, loss: 2806.193359375
# 	[train eval] category 0 AUCROC: 0.890415
# 	[train eval] category 1 AUCROC: 0.890415
# 	[test eval] category 0 AUCROC: 0.801180
# 	[test eval] category 1 AUCROC: 0.801180
# iter: 4000, lr: 0.00065, loss: 2794.833984375
# 	[train eval] category 0 AUCROC: 0.900861
# 	[train eval] category 1 AUCROC: 0.900861
# 	[test eval] category 0 AUCROC: 0.804714
# 	[test eval] category 1 AUCROC: 0.804714
# iter: 5000, lr: 0.00050, loss: 2769.4130859375
# 	[train eval] category 0 AUCROC: 0.908175
# 	[train eval] category 1 AUCROC: 0.908175
# 	[test eval] category 0 AUCROC: 0.802827
# 	[test eval] category 1 AUCROC: 0.802827
# iter: 6000, lr: 0.00035, loss: 2769.435546875
# 	[train eval] category 0 AUCROC: 0.911275
# 	[train eval] category 1 AUCROC: 0.911275
# 	[test eval] category 0 AUCROC: 0.805638
# 	[test eval] category 1 AUCROC: 0.805638
# iter: 7000, lr: 0.00021, loss: 2767.15380859375
# 	[train eval] category 0 AUCROC: 0.914279
# 	[train eval] category 1 AUCROC: 0.914279
# 	[test eval] category 0 AUCROC: 0.807221
# 	[test eval] category 1 AUCROC: 0.807221
# iter: 8000, lr: 0.00010, loss: 2741.69921875
# 	[train eval] category 0 AUCROC: 0.914824
# 	[train eval] category 1 AUCROC: 0.914824
# 	[test eval] category 0 AUCROC: 0.807538
# 	[test eval] category 1 AUCROC: 0.807538
# iter: 9000, lr: 0.00002, loss: 2746.154052734375
# 	[train eval] category 0 AUCROC: 0.915715
# 	[train eval] category 1 AUCROC: 0.915715
# 	[test eval] category 0 AUCROC: 0.806791
# 	[test eval] category 1 AUCROC: 0.806791
# iter: 10000, lr: 0.00000, loss: 2740.2646484375
# 	[train eval] category 0 AUCROC: 0.915503
# 	[train eval] category 1 AUCROC: 0.915503
# 	[test eval] category 0 AUCROC: 0.807411
# 	[test eval] category 1 AUCROC: 0.807411
# Running GP for cleft_size_log1p_zscore, type = continuous, fold = 2, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7368.22509765625
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 5326.3896484375
# 	[train eval] explained variance: 0.480130
# 	[test eval] explained variance: 0.344608
# iter: 2000, lr: 0.00090, loss: 4854.6611328125
# 	[train eval] explained variance: 0.569109
# 	[test eval] explained variance: 0.370388
# iter: 3000, lr: 0.00079, loss: 4685.1318359375
# 	[train eval] explained variance: 0.595497
# 	[test eval] explained variance: 0.373621
# iter: 4000, lr: 0.00065, loss: 4612.73291015625
# 	[train eval] explained variance: 0.602310
# 	[test eval] explained variance: 0.371938
# iter: 5000, lr: 0.00050, loss: 4575.6328125
# 	[train eval] explained variance: 0.603562
# 	[test eval] explained variance: 0.373105
# iter: 6000, lr: 0.00035, loss: 4552.46826171875
# 	[train eval] explained variance: 0.603072
# 	[test eval] explained variance: 0.372266
# iter: 7000, lr: 0.00021, loss: 4537.28515625
# 	[train eval] explained variance: 0.602051
# 	[test eval] explained variance: 0.372114
# iter: 8000, lr: 0.00010, loss: 4533.80224609375
# 	[train eval] explained variance: 0.602368
# 	[test eval] explained variance: 0.375232
# iter: 9000, lr: 0.00002, loss: 4532.83154296875
# 	[train eval] explained variance: 0.600700
# 	[test eval] explained variance: 0.373549
# iter: 10000, lr: 0.00000, loss: 4530.8115234375
# 	[train eval] explained variance: 0.602179
# 	[test eval] explained variance: 0.373866
# Running GP for presyn_soma_dist_log1p_zscore, type = continuous, fold = 2, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7226.787109375
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 5584.6435546875
# 	[train eval] explained variance: 0.193369
# 	[test eval] explained variance: 0.016330
# iter: 2000, lr: 0.00090, loss: 5328.412109375
# 	[train eval] explained variance: 0.258290
# 	[test eval] explained variance: 0.010761
# iter: 3000, lr: 0.00079, loss: 5213.39990234375
# 	[train eval] explained variance: 0.277807
# 	[test eval] explained variance: 0.009170
# iter: 4000, lr: 0.00065, loss: 5153.25830078125
# 	[train eval] explained variance: 0.282116
# 	[test eval] explained variance: 0.010780
# iter: 5000, lr: 0.00050, loss: 5126.2109375
# 	[train eval] explained variance: 0.280738
# 	[test eval] explained variance: 0.007593
# iter: 6000, lr: 0.00035, loss: 5103.29345703125
# 	[train eval] explained variance: 0.279922
# 	[test eval] explained variance: 0.007763
# iter: 7000, lr: 0.00021, loss: 5097.37939453125
# 	[train eval] explained variance: 0.279657
# 	[test eval] explained variance: 0.009613
# iter: 8000, lr: 0.00010, loss: 5088.984375
# 	[train eval] explained variance: 0.278516
# 	[test eval] explained variance: 0.010076
# iter: 9000, lr: 0.00002, loss: 5088.60986328125
# 	[train eval] explained variance: 0.279056
# 	[test eval] explained variance: 0.009628
# iter: 10000, lr: 0.00000, loss: 5089.6923828125
# 	[train eval] explained variance: 0.278132
# 	[test eval] explained variance: 0.010092
# Running GP for postsyn_soma_dist_log1p_zscore, type = continuous, fold = 2, control = None
# Number of training data points: 5060
# Number of test data points: 563
# iter: 0, lr: 0.00100, loss: 7342.83447265625
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 4915.36181640625
# 	[train eval] explained variance: 0.533966
# 	[test eval] explained variance: 0.476112
# iter: 2000, lr: 0.00090, loss: 4542.30615234375
# 	[train eval] explained variance: 0.593096
# 	[test eval] explained variance: 0.483618
# iter: 3000, lr: 0.00079, loss: 4386.7001953125
# 	[train eval] explained variance: 0.615253
# 	[test eval] explained variance: 0.478258
# iter: 4000, lr: 0.00065, loss: 4311.6240234375
# 	[train eval] explained variance: 0.620826
# 	[test eval] explained variance: 0.473170
# iter: 5000, lr: 0.00050, loss: 4275.55615234375
# 	[train eval] explained variance: 0.622316
# 	[test eval] explained variance: 0.474620
# iter: 6000, lr: 0.00035, loss: 4250.08447265625
# 	[train eval] explained variance: 0.622931
# 	[test eval] explained variance: 0.471446
# iter: 7000, lr: 0.00021, loss: 4236.73193359375
# 	[train eval] explained variance: 0.623245
# 	[test eval] explained variance: 0.471770
# iter: 8000, lr: 0.00010, loss: 4231.4912109375
# 	[train eval] explained variance: 0.622879
# 	[test eval] explained variance: 0.469183
# iter: 9000, lr: 0.00002, loss: 4226.35791015625
# 	[train eval] explained variance: 0.622944
# 	[test eval] explained variance: 0.470533
# iter: 10000, lr: 0.00000, loss: 4229.25
# 	[train eval] explained variance: 0.622520
# 	[test eval] explained variance: 0.471295
# Running GP for mito_size_pre_vx_log1p_zscore_zi, type = continuous, fold = 2, control = has_mito_pre
# Number of training data points: 3177
# Number of test data points: 340
# iter: 0, lr: 0.00100, loss: 4641.48095703125
# 	[train eval] explained variance: 0.000000
# 	[test eval] explained variance: 0.000000
# iter: 1000, lr: 0.00098, loss: 3433.33447265625
# 	[train eval] explained variance: 0.420399
# 	[test eval] explained variance: 0.228659
